# %%
# !nvidia-smi
# Out:
# Thu May 21 06:13:18 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !git clone https://github.com/megaamongol/UNSW_NB15_Spectrogram-.git
# %cd UNSW_NB15_Spectrogram-
# !ls
# Out:
# Cloning into 'UNSW_NB15_Spectrogram-'...
# remote: Enumerating objects: 48, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 48 (delta 12), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (48/48), 38.28 KiB | 622.00 KiB/s, done.
# Resolving deltas: 100% (12/12), done.
# /content/UNSW_NB15_Spectrogram-
# configs  data  models  notebooks  README.md  results  spectrograms  src

# %%
# !ls src/
# Out:
# check_column.py  evaluate.py	pythonkods.txt	 spectrogram_gen.py  utils.py
# CHKcolumn.py	 preprocess.py	run_pipeline.py  train.py

# %%
# !git pull
# !ls data/processed/
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 6 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 3.07 KiB | 3.07 MiB/s, done.
# From https://github.com/megaamongol/UNSW_NB15_Spectrogram-
#    71dfe73..1431630  main       -> origin/main
# Updating 71dfe73..1431630
# Fast-forward
#  data/processed/label_encoder.pkl | Bin 0 -> 1762 bytes
#  data/processed/scaler.pkl        | Bin 0 -> 2177 bytes
#  2 files changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 data/processed/label_encoder.pkl
#  create mode 100644 data/processed/scaler.pkl
# label_encoder.pkl  scaler.pkl  test.txt

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
DATA_PATH = '/content/drive/MyDrive/Csv/flows_clean.csv'

import os
print(os.path.exists(DATA_PATH))
# Out:
# True

# %%
import os
# Drive дотор хайх
for root, dirs, files in os.walk('/content/drive/MyDrive'):
    for f in files:
        if 'flows_clean' in f:
            print(os.path.join(root, f))
# Out:
# /content/drive/MyDrive/Csv/flows_clean.csv
